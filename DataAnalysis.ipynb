# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
df=pd.read_csv('train_dataset.csv')
test_df=pd.read_csv('test_dataset.csv')

# %% [markdown]
# Reading datasets

# %%
df.columns.values
# Out:
# array(['House ID', 'Built_Date', 'Priced_date', 'Garden', 'dock_dist',
#        'capital_dist', 'royalMarket_dist', 'guardingTower_dist',
#        'river_dist', 'renovation', 'dining', 'bedroom', 'bathroom',
#        'kingVisit', 'curse', 'blessing', 'farm_land', 'location',
#        'holy_tree', 'knight_house_dist', 'builder', 'Golden Grains'],
#       dtype=object)

# %%
df.head()
# Out:
#      House ID  Built_Date  Priced_date  Garden   dock_dist  capital_dist  \
# 0  1848823488        1602         1609     0.0  138.600639      0.256239
# 1  1848823492        1600         1612     1.0   16.254871     26.882222
# 2  1848823497        1600         1608     0.0    6.555428    136.448973
# 3  1848823502        1603         1611     0.0   79.724550     19.885265
# 4  1848823505        1603         1610     0.0  101.541256      0.519507
#
#    royalMarket_dist  guardingTower_dist  river_dist  renovation  \
# 0         69.486467           14.394903   63.109038         0.0
# 1         34.145238          101.052598   53.249336         0.0
# 2         78.445508           88.480988   72.245533         0.0
# 3         92.698917           22.395136    8.059939         0.0
# 4          3.605055           81.449646   35.706541         0.0
#
#        ...        bathroom  kingVisit  curse  blessing  farm_land  location  \
# ...

# %% [markdown]
# First 5 rows data

# %%
test_df.head()
# Out:
#      House ID  Built_Date  Priced_date  Garden   dock_dist  capital_dist  \
# 0  1848889393        1601         1610     0.0  105.449712     63.936036
# 1  1848889399        1605         1611     0.0   10.028074     16.648880
# 2  1848889405        1604         1607     NaN   46.697442      8.799759
# 3  1848889411        1600         1612     0.0    9.797009      8.831161
# 4  1848889413        1603         1612     NaN   51.371900     32.903303
#
#    royalMarket_dist  guardingTower_dist  river_dist  renovation  \
# 0         25.687517          124.656380   32.971288         NaN
# 1               NaN          148.906420   53.604283         1.0
# 2         33.374570          118.027166    7.347228         0.0
# 3          9.624204          123.956946   24.799455         NaN
# 4               NaN           86.886693    5.552861         1.0
#
#        ...        bathroom  kingVisit  curse  blessing  farm_land  location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16500 entries, 0 to 16499
# Data columns (total 22 columns):
# House ID              16500 non-null int64
# Built_Date            16500 non-null int64
# Priced_date           16500 non-null int64
# Garden                14515 non-null float64
# dock_dist             14859 non-null float64
# capital_dist          15669 non-null float64
# royalMarket_dist      14146 non-null float64
# guardingTower_dist    15956 non-null float64
# river_dist            16500 non-null float64
# renovation            14871 non-null float64
# dining                14862 non-null float64
# bedroom               15851 non-null float64
# bathroom              15536 non-null float64
# kingVisit             16500 non-null int64
# curse                 15502 non-null float64
# blessing              16500 non-null int64
# farm_land             16500 non-null int64
# location              14829 non-null float64
# holy_tree             13234 non-null float64
# ...

# %% [markdown]
# Analysing NaN values and datatypes of each features in training dataset

# %% [markdown]
# Max NaN is in holy_tree feature

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 22 columns):
# House ID              3500 non-null int64
# Built_Date            3500 non-null int64
# Priced_date           3500 non-null int64
# Garden                3071 non-null float64
# dock_dist             3121 non-null float64
# capital_dist          3316 non-null float64
# royalMarket_dist      3029 non-null float64
# guardingTower_dist    3410 non-null float64
# river_dist            3500 non-null float64
# renovation            3136 non-null float64
# dining                3148 non-null float64
# bedroom               3374 non-null float64
# bathroom              3298 non-null float64
# kingVisit             3500 non-null int64
# curse                 3276 non-null float64
# blessing              3500 non-null int64
# farm_land             3500 non-null int64
# location              3134 non-null float64
# holy_tree             2796 non-null float64
# ...

# %% [markdown]
# Here also maximum NaN is in holy_tree

# %%
df.describe()
# Out:
#            House ID    Built_Date   Priced_date        Garden     dock_dist  \
# count  1.650000e+04  16500.000000  16500.000000  14515.000000  14859.000000
# mean   1.848856e+09   1603.004727   1609.500242      0.096659     46.305520
# std    1.898740e+04      2.003839      1.705569      0.295503     35.131047
# min    1.848823e+09   1600.000000   1607.000000      0.000000      0.000288
# 25%    1.848840e+09   1601.000000   1608.000000      0.000000     17.746333
# 50%    1.848856e+09   1603.000000   1609.000000      0.000000     37.969819
# 75%    1.848873e+09   1605.000000   1611.000000      0.000000     68.468817
# max    1.848889e+09   1606.000000   1612.000000      1.000000    157.658673
#
#        capital_dist  royalMarket_dist  guardingTower_dist    river_dist  \
# count  15669.000000      14146.000000        15956.000000  16500.000000
# mean      42.674021         48.715817          101.110421     30.288848
# ...

# %% [markdown]
# More detailed Analysis of dataset

# %%
df['bedroom'].unique()
df.groupby('bedroom').count()
# Out:
#          House ID  Built_Date  Priced_date  Garden  dock_dist  capital_dist  \
# bedroom
# 2.0          5234        5234         5234    4618       4727          4974
# 3.0          5359        5359         5359    4703       4814          5081
# 4.0          5258        5258         5258    4628       4729          4996
#
#          royalMarket_dist  guardingTower_dist  river_dist  renovation  \
# bedroom
# 2.0                  4519                5075        5234        4708
# 3.0                  4598                5176        5359        4855
# 4.0                  4470                5079        5258        4730
#
#              ...        bathroom  kingVisit  curse  blessing  farm_land  \
# bedroom      ...
# 2.0          ...            4940       5234   4946      5234       5234
# 3.0          ...            5049       5359   5028      5359       5359
# 4.0          ...            4938       5258   4921      5258       5258
#
# ...

# %%
df[['builder', 'Golden Grains']].groupby(['builder'], as_index=False).mean().sort_values(by='Golden Grains', ascending=False)
# Out:
#    builder  Golden Grains
# 8      8.0   1.330368e+06
# 3      3.0   1.322103e+06
# 4      4.0   1.313533e+06
# 2      2.0   1.308820e+06
# 5      5.0   1.303461e+06
# 1      1.0   1.300300e+06
# 9      9.0   1.299484e+06
# 6      6.0   1.297946e+06
# 0      0.0   1.296475e+06
# 7      7.0   1.286323e+06

# %% [markdown]
# checked relation between builder and Golden Grains but no any remarkable point

# %%
df=df[:1650]

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = sns.FacetGrid(df, col='location')
g.map(plt.hist, 'Golden Grains', bins=5)

# %%
pd.read_csv('train_dataset.csv')[['location', 'Golden Grains']].groupby(['location'], as_index=False).nunique().sort_values(by='Golden Grains', ascending=False)
# Out:
#    location  Golden Grains
# 1         1           7431
# 0         1           2456
# 2         1           2454
# 3         1           2433

# %% [markdown]
# Looks like location 1 has some advantages, will see more in heatmap and scatter plots in feature analysis file
